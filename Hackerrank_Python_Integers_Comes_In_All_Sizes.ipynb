# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
print((a**b)+(c**d))
