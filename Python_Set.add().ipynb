# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
country = set() 
for i in range(n):
    country.add(input()) 
print(len(country))
