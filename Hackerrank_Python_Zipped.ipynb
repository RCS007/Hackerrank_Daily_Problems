# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Screenshot 2025-04-06 214748.png](<attachment:Screenshot 2025-04-06 214748.png>)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, x = map(int, input().split())
sheet = []
for _ in range (x):
     sheet.append(map(float, input().split()))
for i in zip(*sheet):
    print(sum(i) / len(i))
