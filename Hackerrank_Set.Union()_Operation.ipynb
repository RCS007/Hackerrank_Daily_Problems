# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = int(input())
SET_A = set(map(int,input().split()))

B = int(input())
SET_B = set(map(int,input().split()))

SET_N = SET_A.union(SET_B)
print(len(SET_N))
